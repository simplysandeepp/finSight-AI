# %% [markdown]
# # Financial Advisor EDA
#
# Starter notebook for exploring synthetic financial data.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('../out/synthetic_financials.csv')
df.head()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='scenario', y='revenue_growth', data=df)
plt.title('Revenue Growth by Scenario')
